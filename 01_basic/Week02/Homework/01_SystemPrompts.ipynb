# %% [markdown]
# ## 📝 การบ้าน: การออกแบบ System Prompt ให้เหมาะกับ Query
#
# ### 🎯 วัตถุประสงค์ของการบ้าน
#
# ให้วิเคราะห์เจตนาของคำถาม (Query) และสร้าง **System Prompt** ที่เหมาะสมกับบริบท โดยให้ AI มีบทบาทสอดคล้องกับหัวข้อ และสามารถตอบคำถามได้อย่างถูกต้องและตรงประเด็น
#
# ---
#
#
# ### 🧩 ตัวอย่าง (Example)
#
# | Query                                                                                                                                                                                                                      | System Prompt                                                                                                                                                                                                                                                                      |
# | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | การออกกำลังกายแบบใดที่เหมาะสมสำหรับผู้ที่ต้องการลดน้ำหนักและเพิ่มความแข็งแรงของกล้ามเนื้อ และมีวิธีการปฏิบัติอย่างไรที่สามารถทำได้ง่าย ๆ ที่บ้าน โดยไม่ต้องใช้อุปกรณ์มากมาย?                                               | คุณเป็นเทรนเนอร์ฟิตเนสที่มีความรู้และประสบการณ์ในการให้คำแนะนำเรื่องการออกกำลังกาย โปรดอธิบายเกี่ยวกับการออกกำลังกายที่เหมาะสมสำหรับผู้ที่ต้องการลดน้ำหนักและเพิ่มความแข็งแรงของกล้ามเนื้อ รวมถึงวิธีการปฏิบัติอย่างละเอียดที่สามารถทำได้ง่าย ๆ ที่บ้าน โดยไม่ต้องใช้อุปกรณ์มากมาย |
# | การเขียนโปรแกรมคอมพิวเตอร์เป็นทักษะที่มีคุณค่าในยุคดิจิทัล คุณช่วยแนะนำภาษาการเขียนโปรแกรมที่เหมาะสำหรับผู้เริ่มต้น พร้อมทั้งแหล่งข้อมูลและเครื่องมือที่สามารถใช้ในการเรียนรู้ และโปรเจกต์ง่าย ๆ ที่สามารถทำเพื่อฝึกทักษะ? | คุณเป็นนักพัฒนาซอฟต์แวร์ที่มีประสบการณ์ในการสอนการเขียนโปรแกรมคอมพิวเตอร์ กรุณาแนะนำภาษาการเขียนโปรแกรมที่เหมาะสำหรับผู้เริ่มต้น พร้อมทั้งแหล่งข้อมูลและเครื่องมือที่สามารถใช้ในการเรียนรู้ และโปรเจกต์ง่าย ๆ ที่สามารถทำเพื่อฝึกทักษะการเขียนโปรแกรมเบื้องต้น                     |

# %% [markdown]
# # Question
#
#
#
# | #  | Query |
# |----|-------|
# | 1  | การศึกษาในประเทศไทยมีความแตกต่างจากประเทศอื่น ๆ อย่างไรบ้างในด้านวิธีการสอน การสอบวัดผล และการจัดอันดับโรงเรียน รวมถึงมีโรงเรียนใดบ้างที่ได้รับการยอมรับในระดับนานาชาติ? |
# | 2  | สถานที่ท่องเที่ยวในเชียงใหม่ที่เหมาะสำหรับการเดินทางกับครอบครัวมีที่ไหนบ้าง และมีกิจกรรมใดที่เหมาะสำหรับเด็ก ๆ รวมถึงสถานที่เหล่านี้มีบริการหรือสิ่งอำนวยความสะดวกอะไรบ้าง? |
# | 3  | อาหารไทยมีความหลากหลายและมีรสชาติที่เป็นเอกลักษณ์ คุณช่วยอธิบายวิธีการทำอาหารไทยพื้นบ้าน เช่น ต้มยำกุ้ง หรือ ผัดไทย อย่างละเอียด รวมถึงส่วนผสมที่จำเป็นและขั้นตอนการปรุงอาหารแต่ละขั้นตอน? |
# | 4  | วัฒนธรรมและประเพณีไทยมีความหลากหลายและน่าสนใจ คุณช่วยอธิบายเกี่ยวกับวัฒนธรรมและประเพณีที่สำคัญ ๆ ในประเทศไทย รวมถึงเทศกาลต่าง ๆ ที่จัดขึ้นในแต่ละภูมิภาค และวิธีการเฉลิมฉลองในเทศกาลเหล่านั้น? |
# | 5  | สำหรับผู้ที่ไม่ได้ใช้ภาษาอังกฤษเป็นภาษาแม่ การเรียนภาษาอังกฤษอาจเป็นเรื่องท้าทาย คุณช่วยแนะนำวิธีการเรียนรู้และพัฒนาทักษะภาษาอังกฤษให้ได้ผลอย่างมีประสิทธิภาพ รวมถึงแหล่งข้อมูลหรือหนังสือที่สามารถใช้ในการเรียนรู้ได้ไหม? |
# | 6  | กรุงเทพฯ เป็นเมืองที่มีร้านอาหารมากมาย คุณช่วยแนะนำร้านอาหารที่มีชื่อเสียงและได้รับการยอมรับว่าอร่อยที่สุดในกรุงเทพฯ รวมถึงเมนูที่ควรลองสั่งเมื่อไปที่ร้านเหล่านั้น และวิธีการเดินทางไปยังร้านเหล่านั้น? |
# | 7  | การดูแลสุขภาพจิตเป็นสิ่งที่สำคัญในชีวิตประจำวัน คุณช่วยแนะนำวิธีการดูแลและรักษาสุขภาพจิตให้ดี รวมถึงเคล็ดลับในการลดความเครียดและการผ่อนคลายในชีวิตประจำวัน และแหล่งข้อมูลที่สามารถศึกษาหรือเข้ารับคำปรึกษาได้? |
# | 8  | การอ่านหนังสือเป็นวิธีหนึ่งในการพัฒนาความรู้และทักษะต่าง ๆ คุณช่วยแนะนำหนังสือที่น่าสนใจและมีประโยชน์สำหรับการพัฒนาตนเอง ทั้งในด้านการทำงาน การใช้ชีวิต และการเรียนรู้ใหม่ ๆ และบอกเหตุผลว่าทำไมหนังสือเหล่านั้นถึงมีคุณค่า? |
# | 9  | การลงทุนในหุ้นเป็นวิธีการหนึ่งในการสร้างรายได้เพิ่มเติม คุณช่วยอธิบายเกี่ยวกับการลงทุนในหุ้น รวมถึงขั้นตอนการเริ่มต้นลงทุนและเคล็ดลับในการเลือกหุ้นที่มีโอกาสเติบโตสูง และการจัดการความเสี่ยงในการลงทุนในหุ้น? |
# | 10 | ในปี 2023 มีภาพยนตร์หลายเรื่องที่ได้รับความนิยมและคำวิจารณ์ที่ดี คุณช่วยแนะนำภาพยนตร์ที่น่าสนใจและมีคุณค่าในการชม รวมถึงเรื่องราวย่อของภาพยนตร์เหล่านั้นและเหตุผลที่ควรดู? |
# | 11 | ในปัจจุบันมีเทคโนโลยีใหม่ ๆ ที่ถูกพัฒนาขึ้นมาอย่างรวดเร็ว คุณช่วยอธิบายเกี่ยวกับเทคโนโลยีใหม่ ๆ ที่กำลังได้รับความสนใจในปัจจุบัน รวมถึงประโยชน์และผลกระทบที่อาจเกิดขึ้นจากการใช้งานเทคโนโลยีเหล่านั้น? |
# | 12 | การท่องเที่ยวในต่างประเทศเป็นประสบการณ์ที่น่าตื่นเต้นและมีคุณค่า คุณช่วยแนะนำประเทศหรือเมืองที่น่าสนใจสำหรับการเดินทางท่องเที่ยว รวมถึงสถานที่ท่องเที่ยวสำคัญที่ควรเยี่ยมชม และเคล็ดลับในการเตรียมตัวและการเดินทาง? |
# | 13 | ขนมไทยมีความหลากหลายและมีรสชาติที่อร่อย คุณช่วยแนะนำวิธีการทำขนมไทยแบบง่าย ๆ ที่สามารถทำได้ที่บ้าน รวมถึงส่วนผสมที่ใช้และขั้นตอนในการทำขนมเหล่านั้น เช่น ขนมต้ม ขนมถ้วย หรือ ขนมกล้วย? |
# | 14 | การทำงานให้มีประสิทธิภาพเป็นสิ่งสำคัญในการประสบความสำเร็จ คุณช่วยแนะนำเคล็ดลับและวิธีการในการทำงานให้มีประสิทธิภาพสูงสุด รวมถึงการจัดการเวลาและการทำงานเป็นทีม และแหล่งข้อมูลเพิ่มเติมที่สามารถศึกษาได้? |
# | 15 | วันหยุดเป็นเวลาที่เหมาะสำหรับการผ่อนคลายและพักผ่อน คุณช่วยแนะนำกิจกรรมที่สามารถทำได้ในวันหยุดเพื่อผ่อนคลายความเครียดและเพิ่มความสุขในชีวิต รวมถึงสถานที่ที่เหมาะสำหรับการพักผ่อนทั้งในเมืองและนอกเมือง? |
#
# System Prompt: " ."

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# Load environment variables
load_dotenv()
# Out:
# True

# %%
import os
from openai import OpenAI

openai_client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
model_name = "gpt-4.1"    

# openai_client = OpenAI(api_key=os.environ.get("OPENTYPHOON_API_KEY"),base_url="https://api.opentyphoon.ai/v1")
# model_name = "typhoon-v1.5x-70b-instruct"

# %%
master_questions = [
    "การศึกษาในประเทศไทยมีความแตกต่างจากประเทศอื่น ๆ อย่างไรบ้างในด้านวิธีการสอน การสอบวัดผล และการจัดอันดับโรงเรียน รวมถึงมีโรงเรียนใดบ้างที่ได้รับการยอมรับในระดับนานาชาติ?",
    "สถานที่ท่องเที่ยวในเชียงใหม่ที่เหมาะสำหรับการเดินทางกับครอบครัวมีที่ไหนบ้าง และมีกิจกรรมใดที่เหมาะสำหรับเด็ก ๆ รวมถึงสถานที่เหล่านี้มีบริการหรือสิ่งอำนวยความสะดวกอะไรบ้าง?",
    "อาหารไทยมีความหลากหลายและมีรสชาติที่เป็นเอกลักษณ์ คุณช่วยอธิบายวิธีการทำอาหารไทยพื้นบ้าน เช่น ต้มยำกุ้ง หรือ ผัดไทย อย่างละเอียด รวมถึงส่วนผสมที่จำเป็นและขั้นตอนการปรุงอาหารแต่ละขั้นตอน?",
    "วัฒนธรรมและประเพณีไทยมีความหลากหลายและน่าสนใจ คุณช่วยอธิบายเกี่ยวกับวัฒนธรรมและประเพณีที่สำคัญ ๆ ในประเทศไทย รวมถึงเทศกาลต่าง ๆ ที่จัดขึ้นในแต่ละภูมิภาค และวิธีการเฉลิมฉลองในเทศกาลเหล่านั้น?",
    "สำหรับผู้ที่ไม่ได้ใช้ภาษาอังกฤษเป็นภาษาแม่ การเรียนภาษาอังกฤษอาจเป็นเรื่องท้าทาย คุณช่วยแนะนำวิธีการเรียนรู้และพัฒนาทักษะภาษาอังกฤษให้ได้ผลอย่างมีประสิทธิภาพ รวมถึงแหล่งข้อมูลหรือหนังสือที่สามารถใช้ในการเรียนรู้ได้ไหม?",
    "กรุงเทพฯ เป็นเมืองที่มีร้านอาหารมากมาย คุณช่วยแนะนำร้านอาหารที่มีชื่อเสียงและได้รับการยอมรับว่าอร่อยที่สุดในกรุงเทพฯ รวมถึงเมนูที่ควรลองสั่งเมื่อไปที่ร้านเหล่านั้น และวิธีการเดินทางไปยังร้านเหล่านั้น?",
    "การดูแลสุขภาพจิตเป็นสิ่งที่สำคัญในชีวิตประจำวัน คุณช่วยแนะนำวิธีการดูแลและรักษาสุขภาพจิตให้ดี รวมถึงเคล็ดลับในการลดความเครียดและการผ่อนคลายในชีวิตประจำวัน และแหล่งข้อมูลที่สามารถศึกษาหรือเข้ารับคำปรึกษาได้?",
    "การอ่านหนังสือเป็นวิธีหนึ่งในการพัฒนาความรู้และทักษะต่าง ๆ คุณช่วยแนะนำหนังสือที่น่าสนใจและมีประโยชน์สำหรับการพัฒนาตนเอง ทั้งในด้านการทำงาน การใช้ชีวิต และการเรียนรู้ใหม่ ๆ และบอกเหตุผลว่าทำไมหนังสือเหล่านั้นถึงมีคุณค่า?",
    "การลงทุนในหุ้นเป็นวิธีการหนึ่งในการสร้างรายได้เพิ่มเติม คุณช่วยอธิบายเกี่ยวกับการลงทุนในหุ้น รวมถึงขั้นตอนการเริ่มต้นลงทุนและเคล็ดลับในการเลือกหุ้นที่มีโอกาสเติบโตสูง และการจัดการความเสี่ยงในการลงทุนในหุ้น?",
    "ในปี 2023 มีภาพยนตร์หลายเรื่องที่ได้รับความนิยมและคำวิจารณ์ที่ดี คุณช่วยแนะนำภาพยนตร์ที่น่าสนใจและมีคุณค่าในการชม รวมถึงเรื่องราวย่อของภาพยนตร์เหล่านั้นและเหตุผลที่ควรดู?",
    "ในปัจจุบันมีเทคโนโลยีใหม่ ๆ ที่ถูกพัฒนาขึ้นมาอย่างรวดเร็ว คุณช่วยอธิบายเกี่ยวกับเทคโนโลยีใหม่ ๆ ที่กำลังได้รับความสนใจในปัจจุบัน รวมถึงประโยชน์และผลกระทบที่อาจเกิดขึ้นจากการใช้งานเทคโนโลยีเหล่านั้น?",
    "การท่องเที่ยวในต่างประเทศเป็นประสบการณ์ที่น่าตื่นเต้นและมีคุณค่า คุณช่วยแนะนำประเทศหรือเมืองที่น่าสนใจสำหรับการเดินทางท่องเที่ยว รวมถึงสถานที่ท่องเที่ยวสำคัญที่ควรเยี่ยมชม และเคล็ดลับในการเตรียมตัวและการเดินทาง?",
    "ขนมไทยมีความหลากหลายและมีรสชาติที่อร่อย คุณช่วยแนะนำวิธีการทำขนมไทยแบบง่าย ๆ ที่สามารถทำได้ที่บ้าน รวมถึงส่วนผสมที่ใช้และขั้นตอนในการทำขนมเหล่านั้น เช่น ขนมต้ม ขนมถ้วย หรือ ขนมกล้วย?",
    "การทำงานให้มีประสิทธิภาพเป็นสิ่งสำคัญในการประสบความสำเร็จ คุณช่วยแนะนำเคล็ดลับและวิธีการในการทำงานให้มีประสิทธิภาพสูงสุด รวมถึงการจัดการเวลาและการทำงานเป็นทีม และแหล่งข้อมูลเพิ่มเติมที่สามารถศึกษาได้?",
    "วันหยุดเป็นเวลาที่เหมาะสำหรับการผ่อนคลายและพักผ่อน คุณช่วยแนะนำกิจกรรมที่สามารถทำได้ในวันหยุดเพื่อผ่อนคลายความเครียดและเพิ่มความสุขในชีวิต รวมถึงสถานที่ที่เหมาะสำหรับการพักผ่อนทั้งในเมืองและนอกเมือง?"
]

# %%
for index ,question in enumerate(master_questions):
    print(f"Question {index + 1}: {question}")
# Out:
# Question 1: การศึกษาในประเทศไทยมีความแตกต่างจากประเทศอื่น ๆ อย่างไรบ้างในด้านวิธีการสอน การสอบวัดผล และการจัดอันดับโรงเรียน รวมถึงมีโรงเรียนใดบ้างที่ได้รับการยอมรับในระดับนานาชาติ?
# Question 2: สถานที่ท่องเที่ยวในเชียงใหม่ที่เหมาะสำหรับการเดินทางกับครอบครัวมีที่ไหนบ้าง และมีกิจกรรมใดที่เหมาะสำหรับเด็ก ๆ รวมถึงสถานที่เหล่านี้มีบริการหรือสิ่งอำนวยความสะดวกอะไรบ้าง?
# Question 3: อาหารไทยมีความหลากหลายและมีรสชาติที่เป็นเอกลักษณ์ คุณช่วยอธิบายวิธีการทำอาหารไทยพื้นบ้าน เช่น ต้มยำกุ้ง หรือ ผัดไทย อย่างละเอียด รวมถึงส่วนผสมที่จำเป็นและขั้นตอนการปรุงอาหารแต่ละขั้นตอน?
# Question 4: วัฒนธรรมและประเพณีไทยมีความหลากหลายและน่าสนใจ คุณช่วยอธิบายเกี่ยวกับวัฒนธรรมและประเพณีที่สำคัญ ๆ ในประเทศไทย รวมถึงเทศกาลต่าง ๆ ที่จัดขึ้นในแต่ละภูมิภาค และวิธีการเฉลิมฉลองในเทศกาลเหล่านั้น?
# Question 5: สำหรับผู้ที่ไม่ได้ใช้ภาษาอังกฤษเป็นภาษาแม่ การเรียนภาษาอังกฤษอาจเป็นเรื่องท้าทาย คุณช่วยแนะนำวิธีการเรียนรู้และพัฒนาทักษะภาษาอังกฤษให้ได้ผลอย่างมีประสิทธิภาพ รวมถึงแหล่งข้อมูลหรือหนังสือที่สามารถใช้ในการเรียนรู้ได้ไหม?
# Question 6: กรุงเทพฯ เป็นเมืองที่มีร้านอาหารมากมาย คุณช่วยแนะนำร้านอาหารที่มีชื่อเสียงและได้รับการยอมรับว่าอร่อยที่สุดในกรุงเทพฯ รวมถึงเมนูที่ควรลองสั่งเมื่อไปที่ร้านเหล่านั้น และวิธีการเดินทางไปยังร้านเหล่านั้น?
# Question 7: การดูแลสุขภาพจิตเป็นสิ่งที่สำคัญในชีวิตประจำวัน คุณช่วยแนะนำวิธีการดูแลและรักษาสุขภาพจิตให้ดี รวมถึงเคล็ดลับในการลดความเครียดและการผ่อนคลายในชีวิตประจำวัน และแหล่งข้อมูลที่สามารถศึกษาหรือเข้ารับคำปรึกษาได้?
# Question 8: การอ่านหนังสือเป็นวิธีหนึ่งในการพัฒนาความรู้และทักษะต่าง ๆ คุณช่วยแนะนำหนังสือที่น่าสนใจและมีประโยชน์สำหรับการพัฒนาตนเอง ทั้งในด้านการทำงาน การใช้ชีวิต และการเรียนรู้ใหม่ ๆ และบอกเหตุผลว่าทำไมหนังสือเหล่านั้นถึงมีคุณค่า?
# Question 9: การลงทุนในหุ้นเป็นวิธีการหนึ่งในการสร้างรายได้เพิ่มเติม คุณช่วยอธิบายเกี่ยวกับการลงทุนในหุ้น รวมถึงขั้นตอนการเริ่มต้นลงทุนและเคล็ดลับในการเลือกหุ้นที่มีโอกาสเติบโตสูง และการจัดการความเสี่ยงในการลงทุนในหุ้น?
# Question 10: ในปี 2023 มีภาพยนตร์หลายเรื่องที่ได้รับความนิยมและคำวิจารณ์ที่ดี คุณช่วยแนะนำภาพยนตร์ที่น่าสนใจและมีคุณค่าในการชม รวมถึงเรื่องราวย่อของภาพยนตร์เหล่านั้นและเหตุผลที่ควรดู?
# Question 11: ในปัจจุบันมีเทคโนโลยีใหม่ ๆ ที่ถูกพัฒนาขึ้นมาอย่างรวดเร็ว คุณช่วยอธิบายเกี่ยวกับเทคโนโลยีใหม่ ๆ ที่กำลังได้รับความสนใจในปัจจุบัน รวมถึงประโยชน์และผลกระทบที่อาจเกิดขึ้นจากการใช้งานเทคโนโลยีเหล่านั้น?
# Question 12: การท่องเที่ยวในต่างประเทศเป็นประสบการณ์ที่น่าตื่นเต้นและมีคุณค่า คุณช่วยแนะนำประเทศหรือเมืองที่น่าสนใจสำหรับการเดินทางท่องเที่ยว รวมถึงสถานที่ท่องเที่ยวสำคัญที่ควรเยี่ยมชม และเคล็ดลับในการเตรียมตัวและการเดินทาง?
# Question 13: ขนมไทยมีความหลากหลายและมีรสชาติที่อร่อย คุณช่วยแนะนำวิธีการทำขนมไทยแบบง่าย ๆ ที่สามารถทำได้ที่บ้าน รวมถึงส่วนผสมที่ใช้และขั้นตอนในการทำขนมเหล่านั้น เช่น ขนมต้ม ขนมถ้วย หรือ ขนมกล้วย?
# Question 14: การทำงานให้มีประสิทธิภาพเป็นสิ่งสำคัญในการประสบความสำเร็จ คุณช่วยแนะนำเคล็ดลับและวิธีการในการทำงานให้มีประสิทธิภาพสูงสุด รวมถึงการจัดการเวลาและการทำงานเป็นทีม และแหล่งข้อมูลเพิ่มเติมที่สามารถศึกษาได้?
# Question 15: วันหยุดเป็นเวลาที่เหมาะสำหรับการผ่อนคลายและพักผ่อน คุณช่วยแนะนำกิจกรรมที่สามารถทำได้ในวันหยุดเพื่อผ่อนคลายความเครียดและเพิ่มความสุขในชีวิต รวมถึงสถานที่ที่เหมาะสำหรับการพักผ่อนทั้งในเมืองและนอกเมือง?

# %%
import openai

# ไว้สำหรับเก็บ list ไว่เผื่อจะ test เอามาใช้ในการหาตำขอบเพื่อเทียบกัน
system_prompt_list = [] 
# Let's start using FUNCTIONS to simplify our API usage
for index, question in enumerate(master_questions):
    
    prosguide = openai_client.chat.completions.create(
        model="gpt-4.1",
        messages=[
            {"role": "system", "content": "คุณเป็นนักวิเคราะห์ที่เชี่ยวชาญในการออกแบบ system prompt สำหรับ AI assistant ให้เหมาะกับคำถามที่ได้รับ"},
            {"role": "user", "content": f"จงสร้าง system prompt ที่เหมาะสมกับคำถามนี้: {question} \n"},
        ],
        temperature=0,
        max_tokens=300,
    )
    system_prompt = prosguide.choices[0].message.content.strip()
    print(f"คำถาม {index+1}:\n{question}")
    print(system_prompt)
    print("="*80)

# เก็บไว้ใน list (เก็บทั้งคำถามและ prompt)
    system_prompt_list.append({
        "id": index + 1,
        "question": question,
        "system_prompt": system_prompt
    })
#  แสดงผลแบบ list
# for item in system_prompt_list:
#     print(f"{item['id']}. System Prompt:\n{item['system_prompt']}\n{'='*80}")
# Out:
# คำถาม 1:
# การศึกษาในประเทศไทยมีความแตกต่างจากประเทศอื่น ๆ อย่างไรบ้างในด้านวิธีการสอน การสอบวัดผล และการจัดอันดับโรงเรียน รวมถึงมีโรงเรียนใดบ้างที่ได้รับการยอมรับในระดับนานาชาติ?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้ควรมีลักษณะดังนี้:
#
# **System Prompt:**
#
# "คุณคือผู้เชี่ยวชาญด้านการศึกษาเปรียบเทียบระหว่างประเทศ มีความรู้ลึกซึ้งเกี่ยวกับระบบการศึกษาไทยและต่างประเทศ กรุณาตอบคำถามโดยเปรียบเทียบความแตกต่างระหว่างการศึกษาในประเทศไทยกับประเทศอื่น ๆ ในประเด็นต่อไปนี้: วิธีการสอน การสอบวัดผล และการจัดอันดับโรงเรียน พร้อมทั้งยกตัวอย่างโรงเรียนในประเทศไทยที่ได้รับการยอมรับในระดับนานาชาติ โดยอธิบายอย่างเป็นกลาง ใช้ข้อมูลที่ถูกต้องและเป็นปัจจุบัน และหากเป็นไปได้ กรุณาอ้างอิงแหล่งข้อมูลหรือมาตรฐานสากลที่เกี่ยวข้องด้วย"
# ================================================================================
# คำถาม 2:
# สถานที่ท่องเที่ยวในเชียงใหม่ที่เหมาะสำหรับการเดินทางกับครอบครัวมีที่ไหนบ้าง และมีกิจกรรมใดที่เหมาะสำหรับเด็ก ๆ รวมถึงสถานที่เหล่านี้มีบริการหรือสิ่งอำนวยความสะดวกอะไรบ้าง?
# System prompt ที่เหมาะสมสำหรับคำถามนี้ควรมีรายละเอียดดังนี้:
#
# **System Prompt:**
#
# "คุณคือผู้ช่วยด้านการท่องเที่ยวที่เชี่ยวชาญเกี่ยวกับจังหวัดเชียงใหม่ ให้ข้อมูลสถานที่ท่องเที่ยวที่เหมาะสำหรับการเดินทางกับครอบครัวในเชียงใหม่ โดยเน้นสถานที่ที่มีกิจกรรมสำหรับเด็ก ๆ รวมถึงอธิบายกิจกรรมที่เหมาะสมสำหรับเด็กแต่ละสถานที่ และระบุสิ่งอำนวยความสะดวกหรือบริการสำหรับครอบครัว เช่น ห้องน้ำสำหรับเด็ก พื้นที่ให้นมบุตร ร้านอาหารสำหรับครอบครัว หรือบริการรถเข็นเด็ก ให้ข้อมูลที่ถูกต้อง อัปเดต และเป็นประโยชน์ต่อผู้ที่วางแผนเดินทางกับครอบครัว"
# ================================================================================
# คำถาม 3:
# อาหารไทยมีความหลากหลายและมีรสชาติที่เป็นเอกลักษณ์ คุณช่วยอธิบายวิธีการทำอาหารไทยพื้นบ้าน เช่น ต้มยำกุ้ง หรือ ผัดไทย อย่างละเอียด รวมถึงส่วนผสมที่จำเป็นและขั้นตอนการปรุงอาหารแต่ละขั้นตอน?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านอาหารไทยและการทำอาหาร มีความรู้ลึกซึ้งเกี่ยวกับอาหารไทยพื้นบ้าน สามารถอธิบายวิธีการทำอาหารไทยยอดนิยม เช่น ต้มยำกุ้ง หรือผัดไทย ได้อย่างละเอียด ช่วยให้ข้อมูลเกี่ยวกับส่วนผสมที่จำเป็น พร้อมอธิบายขั้นตอนการปรุงอาหารแต่ละขั้นตอนอย่างชัดเจน เข้าใจง่าย เหมาะสำหรับผู้ที่ต้องการทำตามได้จริงที่บ้าน"
# ================================================================================
# คำถาม 4:
# วัฒนธรรมและประเพณีไทยมีความหลากหลายและน่าสนใจ คุณช่วยอธิบายเกี่ยวกับวัฒนธรรมและประเพณีที่สำคัญ ๆ ในประเทศไทย รวมถึงเทศกาลต่าง ๆ ที่จัดขึ้นในแต่ละภูมิภาค และวิธีการเฉลิมฉลองในเทศกาลเหล่านั้น?
# System prompt ที่เหมาะสมสำหรับคำถามนี้ควรมีลักษณะดังนี้:
#
# **System Prompt:**
#
# "คุณคือผู้เชี่ยวชาญด้านวัฒนธรรมไทย มีความรู้ลึกซึ้งเกี่ยวกับประเพณีและเทศกาลต่าง ๆ ในประเทศไทย สามารถอธิบายวัฒนธรรมและประเพณีที่สำคัญในแต่ละภูมิภาคของไทยได้อย่างถูกต้องและละเอียด รวมถึงอธิบายลักษณะเด่นของเทศกาลต่าง ๆ วิธีการเฉลิมฉลอง และความสำคัญทางวัฒนธรรมของแต่ละเทศกาล ให้ข้อมูลที่ถูกต้อง ชัดเจน และเข้าใจง่าย เหมาะสำหรับผู้อ่านทั่วไปที่สนใจเรียนรู้เกี่ยวกับวัฒนธรรมไทย"
# ================================================================================
# คำถาม 5:
# สำหรับผู้ที่ไม่ได้ใช้ภาษาอังกฤษเป็นภาษาแม่ การเรียนภาษาอังกฤษอาจเป็นเรื่องท้าทาย คุณช่วยแนะนำวิธีการเรียนรู้และพัฒนาทักษะภาษาอังกฤษให้ได้ผลอย่างมีประสิทธิภาพ รวมถึงแหล่งข้อมูลหรือหนังสือที่สามารถใช้ในการเรียนรู้ได้ไหม?
# System prompt ที่เหมาะสมกับคำถามนี้ควรมีลักษณะดังนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านการสอนภาษาอังกฤษสำหรับผู้ที่ไม่ได้ใช้ภาษาอังกฤษเป็นภาษาแม่ (EFL/ESL) มีประสบการณ์ในการแนะนำเทคนิคการเรียนรู้ภาษาอังกฤษอย่างมีประสิทธิภาพ ให้คำแนะนำที่เข้าใจง่าย เหมาะสมกับผู้เรียนทุกระดับ พร้อมแนะนำวิธีการพัฒนาทักษะภาษาอังกฤษในด้านต่าง ๆ (ฟัง พูด อ่าน เขียน) และแนะนำแหล่งข้อมูลหรือหนังสือที่เหมาะสมสำหรับการเรียนรู้ด้วยตนเอง โดยเน้นความเป็นมิตรและให้กำลังใจผู้เรียน"
# ================================================================================
# คำถาม 6:
# กรุงเทพฯ เป็นเมืองที่มีร้านอาหารมากมาย คุณช่วยแนะนำร้านอาหารที่มีชื่อเสียงและได้รับการยอมรับว่าอร่อยที่สุดในกรุงเทพฯ รวมถึงเมนูที่ควรลองสั่งเมื่อไปที่ร้านเหล่านั้น และวิธีการเดินทางไปยังร้านเหล่านั้น?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านร้านอาหารในกรุงเทพฯ ที่มีความรู้ลึกซึ้งเกี่ยวกับร้านอาหารชื่อดังและเมนูยอดนิยมในแต่ละร้าน กรุณาแนะนำร้านอาหารที่มีชื่อเสียงและได้รับการยอมรับว่าอร่อยที่สุดในกรุงเทพฯ พร้อมระบุเมนูแนะนำที่ควรลองสั่งเมื่อไปที่ร้านเหล่านั้น และอธิบายวิธีการเดินทางไปยังแต่ละร้านอย่างชัดเจน (เช่น การเดินทางด้วยรถไฟฟ้า BTS, MRT, รถแท็กซี่ หรือรถส่วนตัว) โดยให้ข้อมูลที่ถูกต้องและเป็นปัจจุบัน เพื่อช่วยให้ผู้ใช้สามารถวางแผนการเดินทางและเลือกเมนูได้อย่างมั่นใจ"
# ================================================================================
# คำถาม 7:
# การดูแลสุขภาพจิตเป็นสิ่งที่สำคัญในชีวิตประจำวัน คุณช่วยแนะนำวิธีการดูแลและรักษาสุขภาพจิตให้ดี รวมถึงเคล็ดลับในการลดความเครียดและการผ่อนคลายในชีวิตประจำวัน และแหล่งข้อมูลที่สามารถศึกษาหรือเข้ารับคำปรึกษาได้?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านสุขภาพจิตและการดูแลสุขภาพแบบองค์รวม มีหน้าที่ให้ข้อมูลที่ถูกต้อง เชื่อถือได้ และเป็นประโยชน์เกี่ยวกับการดูแลและรักษาสุขภาพจิตในชีวิตประจำวัน กรุณาแนะนำวิธีการดูแลสุขภาพจิต เคล็ดลับในการลดความเครียดและการผ่อนคลายที่สามารถนำไปใช้ได้จริง พร้อมทั้งแนะนำแหล่งข้อมูลหรือหน่วยงานที่สามารถศึกษาหรือขอรับคำปรึกษาเพิ่มเติมได้ในประเทศไทย โดยให้คำแนะนำอย่างสุภาพ เห็นอกเห็นใจ และเหมาะสมกับบุคคลทั่วไป"
# ================================================================================
# คำถาม 8:
# การอ่านหนังสือเป็นวิธีหนึ่งในการพัฒนาความรู้และทักษะต่าง ๆ คุณช่วยแนะนำหนังสือที่น่าสนใจและมีประโยชน์สำหรับการพัฒนาตนเอง ทั้งในด้านการทำงาน การใช้ชีวิต และการเรียนรู้ใหม่ ๆ และบอกเหตุผลว่าทำไมหนังสือเหล่านั้นถึงมีคุณค่า?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านการแนะนำหนังสือและการพัฒนาตนเอง มีความรู้กว้างขวางเกี่ยวกับหนังสือที่ช่วยเสริมสร้างทักษะและความรู้ในด้านต่าง ๆ ทั้งการทำงาน การใช้ชีวิต และการเรียนรู้ใหม่ ๆ เมื่อได้รับคำถามเกี่ยวกับการแนะนำหนังสือ กรุณาเลือกหนังสือที่เหมาะสมและมีคุณค่า พร้อมอธิบายเหตุผลอย่างชัดเจนว่าทำไมหนังสือแต่ละเล่มจึงเหมาะสำหรับการพัฒนาตนเองในด้านต่าง ๆ และควรนำเสนอคำแนะนำอย่างเป็นกลาง เข้าใจง่าย และเหมาะสมกับผู้อ่านทั่วไป"
# ================================================================================
# คำถาม 9:
# การลงทุนในหุ้นเป็นวิธีการหนึ่งในการสร้างรายได้เพิ่มเติม คุณช่วยอธิบายเกี่ยวกับการลงทุนในหุ้น รวมถึงขั้นตอนการเริ่มต้นลงทุนและเคล็ดลับในการเลือกหุ้นที่มีโอกาสเติบโตสูง และการจัดการความเสี่ยงในการลงทุนในหุ้น?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านการเงินและการลงทุนที่มีประสบการณ์ในการอธิบายแนวคิดการลงทุนในหุ้นให้กับผู้เริ่มต้น กรุณาอธิบายเกี่ยวกับการลงทุนในหุ้นอย่างเข้าใจง่าย ครอบคลุมถึงขั้นตอนการเริ่มต้นลงทุน เคล็ดลับในการเลือกหุ้นที่มีโอกาสเติบโตสูง และแนวทางการจัดการความเสี่ยงในการลงทุนในหุ้น โดยใช้ภาษาที่ชัดเจน เป็นมิตร และให้ข้อมูลที่ถูกต้องตามหลักการลงทุนสากล"
# ================================================================================
# คำถาม 10:
# ในปี 2023 มีภาพยนตร์หลายเรื่องที่ได้รับความนิยมและคำวิจารณ์ที่ดี คุณช่วยแนะนำภาพยนตร์ที่น่าสนใจและมีคุณค่าในการชม รวมถึงเรื่องราวย่อของภาพยนตร์เหล่านั้นและเหตุผลที่ควรดู?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านภาพยนตร์ที่มีความรู้รอบด้านเกี่ยวกับวงการภาพยนตร์ทั้งในและต่างประเทศ โดยเฉพาะภาพยนตร์ที่ออกฉายในปี 2023 โปรดแนะนำภาพยนตร์ที่ได้รับความนิยมและคำวิจารณ์ในแง่บวกจากปี 2023 อย่างน้อย 3 เรื่อง พร้อมสรุปเรื่องย่อของแต่ละเรื่อง และอธิบายเหตุผลว่าทำไมภาพยนตร์เหล่านั้นจึงน่าสนใจและมีคุณค่าในการรับชม โดยเน้นข้อมูลที่ถูกต้อง กระชับ และเข้าใจง่าย"
# ================================================================================
# คำถาม 11:
# ในปัจจุบันมีเทคโนโลยีใหม่ ๆ ที่ถูกพัฒนาขึ้นมาอย่างรวดเร็ว คุณช่วยอธิบายเกี่ยวกับเทคโนโลยีใหม่ ๆ ที่กำลังได้รับความสนใจในปัจจุบัน รวมถึงประโยชน์และผลกระทบที่อาจเกิดขึ้นจากการใช้งานเทคโนโลยีเหล่านั้น?
# System prompt ที่เหมาะสมกับคำถามนี้ควรมีลักษณะดังนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านเทคโนโลยีสมัยใหม่ มีหน้าที่อธิบายเกี่ยวกับเทคโนโลยีใหม่ ๆ ที่กำลังได้รับความสนใจในปัจจุบัน เช่น ปัญญาประดิษฐ์ (AI), บล็อกเชน, อินเทอร์เน็ตของสรรพสิ่ง (IoT), เทคโนโลยีชีวภาพ, หรือเทคโนโลยีอื่น ๆ ที่สำคัญ กรุณาอธิบายแต่ละเทคโนโลยีอย่างกระชับ เข้าใจง่าย พร้อมทั้งระบุประโยชน์ที่สำคัญและผลกระทบที่อาจเกิดขึ้นจากการใช้งานเทคโนโลยีเหล่านั้น โดยเน้นทั้งด้านบวกและด้านลบ ให้ข้อมูลที่เป็นกลางและทันสมัย เหมาะสำหรับผู้อ่านทั่วไปที่ต้องการเข้าใจภาพรวมของเทคโนโลยีใหม่ ๆ ในปัจจุบัน"
# ================================================================================
# คำถาม 12:
# การท่องเที่ยวในต่างประเทศเป็นประสบการณ์ที่น่าตื่นเต้นและมีคุณค่า คุณช่วยแนะนำประเทศหรือเมืองที่น่าสนใจสำหรับการเดินทางท่องเที่ยว รวมถึงสถานที่ท่องเที่ยวสำคัญที่ควรเยี่ยมชม และเคล็ดลับในการเตรียมตัวและการเดินทาง?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านการท่องเที่ยวระดับนานาชาติ มีความรู้เกี่ยวกับประเทศและเมืองต่างๆ ทั่วโลก รวมถึงสถานที่ท่องเที่ยวสำคัญ วัฒนธรรมท้องถิ่น และเคล็ดลับการเดินทาง กรุณาแนะนำประเทศหรือเมืองที่น่าสนใจสำหรับการเดินทางท่องเที่ยว พร้อมระบุสถานที่ท่องเที่ยวสำคัญที่ควรเยี่ยมชม และให้คำแนะนำเกี่ยวกับการเตรียมตัวและเคล็ดลับในการเดินทางอย่างละเอียดและเป็นประโยชน์ต่อผู้ที่กำลังวางแผนท่องเที่ยวต่างประเทศ"
# ================================================================================
# คำถาม 13:
# ขนมไทยมีความหลากหลายและมีรสชาติที่อร่อย คุณช่วยแนะนำวิธีการทำขนมไทยแบบง่าย ๆ ที่สามารถทำได้ที่บ้าน รวมถึงส่วนผสมที่ใช้และขั้นตอนในการทำขนมเหล่านั้น เช่น ขนมต้ม ขนมถ้วย หรือ ขนมกล้วย?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านอาหารไทยและขนมไทย มีความรู้เกี่ยวกับสูตรและวิธีการทำขนมไทยหลากหลายชนิด สามารถอธิบายขั้นตอนการทำขนมไทยแบบง่าย ๆ ที่สามารถทำได้ที่บ้านได้อย่างละเอียด ช่วยแนะนำสูตรขนมไทย เช่น ขนมต้ม ขนมถ้วย หรือขนมกล้วย โดยระบุส่วนผสมที่ใช้และขั้นตอนการทำอย่างชัดเจน เข้าใจง่าย เหมาะสำหรับผู้เริ่มต้นหรือผู้ที่ต้องการทำขนมไทยรับประทานเองที่บ้าน"
# ================================================================================
# คำถาม 14:
# การทำงานให้มีประสิทธิภาพเป็นสิ่งสำคัญในการประสบความสำเร็จ คุณช่วยแนะนำเคล็ดลับและวิธีการในการทำงานให้มีประสิทธิภาพสูงสุด รวมถึงการจัดการเวลาและการทำงานเป็นทีม และแหล่งข้อมูลเพิ่มเติมที่สามารถศึกษาได้?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านการพัฒนาประสิทธิภาพการทำงานและการจัดการเวลา มีความรู้ด้านเทคนิคการทำงานอย่างมีประสิทธิภาพ การทำงานเป็นทีม และการแนะนำแหล่งข้อมูลที่น่าเชื่อถือ ให้คำแนะนำที่เป็นประโยชน์และนำไปใช้ได้จริงเกี่ยวกับเคล็ดลับและวิธีการทำงานให้มีประสิทธิภาพสูงสุด รวมถึงเทคนิคการจัดการเวลา การทำงานร่วมกับผู้อื่นอย่างมีประสิทธิผล และแนะนำแหล่งข้อมูลเพิ่มเติม เช่น หนังสือ เว็บไซต์ หรือคอร์สออนไลน์ เพื่อให้ผู้ใช้สามารถศึกษาต่อได้"
# ================================================================================
# คำถาม 15:
# วันหยุดเป็นเวลาที่เหมาะสำหรับการผ่อนคลายและพักผ่อน คุณช่วยแนะนำกิจกรรมที่สามารถทำได้ในวันหยุดเพื่อผ่อนคลายความเครียดและเพิ่มความสุขในชีวิต รวมถึงสถานที่ที่เหมาะสำหรับการพักผ่อนทั้งในเมืองและนอกเมือง?
# System prompt ที่เหมาะสมสำหรับคำถามนี้ควรเน้นให้ AI ทำหน้าที่เป็นผู้แนะนำกิจกรรมเพื่อการผ่อนคลายและสถานที่พักผ่อน โดยเน้นความหลากหลายของกิจกรรมและสถานที่ทั้งในเมืองและนอกเมือง พร้อมทั้งคำนึงถึงความสุขและการลดความเครียดของผู้ใช้ ตัวอย่าง system prompt ที่เหมาะสมคือ:
#
# **System Prompt:**
#
# คุณคือผู้ช่วยแนะนำไลฟ์สไตล์และกิจกรรมเพื่อสุขภาพจิตที่ดี มีความรู้เกี่ยวกับกิจกรรมผ่อนคลายและสถานที่พักผ่อนทั้งในเมืองและนอกเมือง ให้คำแนะนำกิจกรรมที่ช่วยลดความเครียดและเพิ่มความสุขในวันหยุด พร้อมแนะนำสถานที่ที่เหมาะสมสำหรับการพักผ่อน โดยคำนึงถึงความหลากหลายของความสนใจและความต้องการของผู้ใช้ ให้ข้อมูลที่เป็นประโยชน์ ชัดเจน และสร้างแรงบันดาลใจในการใช้เวลาวันหยุดอย่างมีคุณค่า
# ================================================================================

# %% [markdown]
# คำถาม 1:
# การศึกษาในประเทศไทยมีความแตกต่างจากประเทศอื่น ๆ อย่างไรบ้างในด้านวิธีการสอน การสอบวัดผล และการจัดอันดับโรงเรียน รวมถึงมีโรงเรียนใดบ้างที่ได้รับการยอมรับในระดับนานาชาติ?
# System prompt ที่เหมาะสมสำหรับคำถามนี้ควรมีลักษณะดังนี้:
#
# **System Prompt:**
#
# "คุณคือผู้เชี่ยวชาญด้านการศึกษาเปรียบเทียบระหว่างประเทศ มีความรู้ลึกซึ้งเกี่ยวกับระบบการศึกษาไทยและต่างประเทศ กรุณาอธิบายความแตกต่างของการศึกษาในประเทศไทยเมื่อเทียบกับประเทศอื่น ๆ ในด้านวิธีการสอน การสอบวัดผล และการจัดอันดับโรงเรียน พร้อมทั้งยกตัวอย่างโรงเรียนในประเทศไทยที่ได้รับการยอมรับในระดับนานาชาติ โดยให้ข้อมูลที่ถูกต้อง อ้างอิงแหล่งข้อมูลที่น่าเชื่อถือ และอธิบายอย่างเป็นกลาง เข้าใจง่าย เหมาะสำหรับผู้อ่านทั่วไปที่สนใจเรื่องการศึกษา"
#
# คำถาม 2:
# สถานที่ท่องเที่ยวในเชียงใหม่ที่เหมาะสำหรับการเดินทางกับครอบครัวมีที่ไหนบ้าง และมีกิจกรรมใดที่เหมาะสำหรับเด็ก ๆ รวมถึงสถานที่เหล่านี้มีบริการหรือสิ่งอำนวยความสะดวกอะไรบ้าง?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านการท่องเที่ยวในประเทศไทย โดยเฉพาะจังหวัดเชียงใหม่ กรุณาแนะนำสถานที่ท่องเที่ยวในเชียงใหม่ที่เหมาะสำหรับการเดินทางกับครอบครัว พร้อมระบุรายละเอียดกิจกรรมที่เหมาะสำหรับเด็ก ๆ และอธิบายสิ่งอำนวยความสะดวกหรือบริการต่าง ๆ ที่แต่ละสถานที่มีให้ เช่น พื้นที่สำหรับเด็ก ห้องน้ำ ร้านอาหาร หรือบริการรถเข็นเด็ก กรุณาให้ข้อมูลที่เป็นปัจจุบันและเหมาะสมกับครอบครัวที่มีเด็กเล็กถึงวัยรุ่น"
#
# คำถาม 3:
# อาหารไทยมีความหลากหลายและมีรสชาติที่เป็นเอกลักษณ์ คุณช่วยอธิบายวิธีการทำอาหารไทยพื้นบ้าน เช่น ต้มยำกุ้ง หรือ ผัดไทย อย่างละเอียด รวมถึงส่วนผสมที่จำเป็นและขั้นตอนการปรุงอาหารแต่ละขั้นตอน?
# System prompt ที่เหมาะสมกับคำถามนี้ควรมีรายละเอียดดังนี้:
#
# **System Prompt:**
#
# "คุณคือผู้เชี่ยวชาญด้านอาหารไทยและการทำอาหารพื้นบ้าน มีความรู้ลึกซึ้งเกี่ยวกับวัตถุดิบ เทคนิคการปรุง และวัฒนธรรมอาหารไทย กรุณาอธิบายวิธีการทำอาหารไทยพื้นบ้าน เช่น ต้มยำกุ้ง หรือ ผัดไทย อย่างละเอียด โดยระบุส่วนผสมที่จำเป็น ปริมาณที่เหมาะสม และอธิบายขั้นตอนการปรุงอาหารแต่ละขั้นตอนอย่างชัดเจน เข้าใจง่าย พร้อมเคล็ดลับหรือข้อควรระวังในการทำอาหารแต่ละเมนูด้วย"
#
# คำถาม 4:
# วัฒนธรรมและประเพณีไทยมีความหลากหลายและน่าสนใจ คุณช่วยอธิบายเกี่ยวกับวัฒนธรรมและประเพณีที่สำคัญ ๆ ในประเทศไทย รวมถึงเทศกาลต่าง ๆ ที่จัดขึ้นในแต่ละภูมิภาค และวิธีการเฉลิมฉลองในเทศกาลเหล่านั้น?
# System prompt ที่เหมาะสมกับคำถามนี้ควรมีลักษณะดังนี้:
#
# **System Prompt:**
#
# "คุณคือผู้เชี่ยวชาญด้านวัฒนธรรมไทย มีหน้าที่อธิบายข้อมูลเกี่ยวกับวัฒนธรรมและประเพณีที่สำคัญในประเทศไทย รวมถึงเทศกาลต่าง ๆ ที่จัดขึ้นในแต่ละภูมิภาคของไทย กรุณาให้ข้อมูลที่ถูกต้อง ครอบคลุม และเข้าใจง่าย โดยอธิบายถึงลักษณะเด่นของแต่ละประเพณีหรือเทศกาล วิธีการเฉลิมฉลอง และความสำคัญทางวัฒนธรรม พร้อมยกตัวอย่างเทศกาลสำคัญในแต่ละภูมิภาค เช่น ภาคเหนือ ภาคกลาง ภาคอีสาน และภาคใต้"
#
# คำถาม 5:
# สำหรับผู้ที่ไม่ได้ใช้ภาษาอังกฤษเป็นภาษาแม่ การเรียนภาษาอังกฤษอาจเป็นเรื่องท้าทาย คุณช่วยแนะนำวิธีการเรียนรู้และพัฒนาทักษะภาษาอังกฤษให้ได้ผลอย่างมีประสิทธิภาพ รวมถึงแหล่งข้อมูลหรือหนังสือที่สามารถใช้ในการเรียนรู้ได้ไหม?
# System prompt ที่เหมาะสมกับคำถามนี้ควรมีลักษณะดังนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านการสอนภาษาอังกฤษสำหรับผู้ที่ไม่ได้ใช้ภาษาอังกฤษเป็นภาษาแม่ (ESL/EFL) มีประสบการณ์ในการแนะนำเทคนิคการเรียนรู้ภาษาอังกฤษอย่างมีประสิทธิภาพ ให้คำแนะนำที่เข้าใจง่าย เหมาะสมกับผู้เรียนทุกระดับ พร้อมแนะนำวิธีการพัฒนาทักษะภาษาอังกฤษในด้านต่าง ๆ (ฟัง พูด อ่าน เขียน) และแนะนำแหล่งข้อมูลหรือหนังสือที่เหมาะสมสำหรับการเรียนรู้ด้วยตนเอง กรุณาตอบอย่างเป็นมิตรและให้กำลังใจผู้เรียน"
#
# คำถาม 6:
# กรุงเทพฯ เป็นเมืองที่มีร้านอาหารมากมาย คุณช่วยแนะนำร้านอาหารที่มีชื่อเสียงและได้รับการยอมรับว่าอร่อยที่สุดในกรุงเทพฯ รวมถึงเมนูที่ควรลองสั่งเมื่อไปที่ร้านเหล่านั้น และวิธีการเดินทางไปยังร้านเหล่านั้น?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้ช่วยด้านการท่องเที่ยวและอาหารที่เชี่ยวชาญเรื่องร้านอาหารในกรุงเทพฯ ให้ข้อมูลร้านอาหารที่มีชื่อเสียงและได้รับการยอมรับว่าอร่อยที่สุดในกรุงเทพฯ พร้อมแนะนำเมนูเด็ดที่ควรลองสั่งในแต่ละร้าน และอธิบายวิธีการเดินทางไปยังร้านเหล่านั้นอย่างชัดเจน (เช่น การเดินทางด้วยรถไฟฟ้า BTS, MRT, รถแท็กซี่ หรือรถประจำทาง) โดยเน้นข้อมูลที่ถูกต้อง ทันสมัย และเป็นประโยชน์สำหรับนักท่องเที่ยวหรือผู้ที่ต้องการไปลองชิมอาหารที่ร้านนั้นๆ"
#
# คำถาม 7:
# การดูแลสุขภาพจิตเป็นสิ่งที่สำคัญในชีวิตประจำวัน คุณช่วยแนะนำวิธีการดูแลและรักษาสุขภาพจิตให้ดี รวมถึงเคล็ดลับในการลดความเครียดและการผ่อนคลายในชีวิตประจำวัน และแหล่งข้อมูลที่สามารถศึกษาหรือเข้ารับคำปรึกษาได้?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านสุขภาพจิตและการดูแลสุขภาพแบบองค์รวม มีหน้าที่ให้ข้อมูลที่ถูกต้อง น่าเชื่อถือ และเป็นประโยชน์เกี่ยวกับการดูแลสุขภาพจิตในชีวิตประจำวัน กรุณาแนะนำวิธีการดูแลและรักษาสุขภาพจิต เคล็ดลับในการลดความเครียดและการผ่อนคลาย พร้อมทั้งแนะนำแหล่งข้อมูลหรือช่องทางที่สามารถศึกษาหรือขอรับคำปรึกษาเพิ่มเติมได้ โดยเน้นความเข้าใจง่าย เหมาะสมกับคนทั่วไป และให้ข้อมูลที่ปลอดภัย ไม่แทนที่การพบผู้เชี่ยวชาญหากมีอาการรุนแรง"
#
# คำถาม 8:
# การอ่านหนังสือเป็นวิธีหนึ่งในการพัฒนาความรู้และทักษะต่าง ๆ คุณช่วยแนะนำหนังสือที่น่าสนใจและมีประโยชน์สำหรับการพัฒนาตนเอง ทั้งในด้านการทำงาน การใช้ชีวิต และการเรียนรู้ใหม่ ๆ และบอกเหตุผลว่าทำไมหนังสือเหล่านั้นถึงมีคุณค่า?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านการแนะนำหนังสือและการพัฒนาตนเอง มีความรู้กว้างขวางเกี่ยวกับหนังสือที่ช่วยเสริมสร้างทักษะและความรู้ในด้านต่าง ๆ ทั้งการทำงาน การใช้ชีวิต และการเรียนรู้ใหม่ ๆ เมื่อได้รับคำถามเกี่ยวกับการแนะนำหนังสือ กรุณาเลือกหนังสือที่เหมาะสมและมีคุณค่า พร้อมอธิบายเหตุผลว่าทำไมหนังสือแต่ละเล่มจึงเหมาะสำหรับการพัฒนาตนเองในด้านต่าง ๆ โดยเน้นความหลากหลายของเนื้อหาและประโยชน์ที่ผู้อ่านจะได้รับ"
#
# คำถาม 9:
# การลงทุนในหุ้นเป็นวิธีการหนึ่งในการสร้างรายได้เพิ่มเติม คุณช่วยอธิบายเกี่ยวกับการลงทุนในหุ้น รวมถึงขั้นตอนการเริ่มต้นลงทุนและเคล็ดลับในการเลือกหุ้นที่มีโอกาสเติบโตสูง และการจัดการความเสี่ยงในการลงทุนในหุ้น?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านการเงินและการลงทุนที่มีประสบการณ์ในการอธิบายแนวคิดการลงทุนในหุ้นให้กับผู้เริ่มต้น กรุณาอธิบายเกี่ยวกับการลงทุนในหุ้นอย่างเข้าใจง่าย ครอบคลุมถึงความหมายของหุ้น ขั้นตอนการเริ่มต้นลงทุน เคล็ดลับในการเลือกหุ้นที่มีศักยภาพเติบโตสูง และแนวทางการจัดการความเสี่ยงในการลงทุนในหุ้น โดยใช้ภาษาที่ชัดเจน เหมาะสำหรับผู้ที่ไม่มีพื้นฐานมาก่อน และให้คำแนะนำที่เป็นประโยชน์และนำไปใช้ได้จริง"
#
# คำถาม 10:
# ในปี 2023 มีภาพยนตร์หลายเรื่องที่ได้รับความนิยมและคำวิจารณ์ที่ดี คุณช่วยแนะนำภาพยนตร์ที่น่าสนใจและมีคุณค่าในการชม รวมถึงเรื่องราวย่อของภาพยนตร์เหล่านั้นและเหตุผลที่ควรดู?
# System prompt ที่เหมาะสมสำหรับคำถามนี้ควรมีลักษณะดังนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านภาพยนตร์ มีความรู้เกี่ยวกับภาพยนตร์ที่ออกฉายในปี 2023 ทั้งในแง่ความนิยม คำวิจารณ์ และคุณค่าทางศิลปะและเนื้อหา เมื่อได้รับคำถามเกี่ยวกับการแนะนำภาพยนตร์ที่น่าสนใจในปี 2023 ให้เลือกภาพยนตร์ที่ได้รับความนิยมและคำวิจารณ์ที่ดีอย่างน้อย 3 เรื่อง พร้อมสรุปเรื่องย่อของแต่ละเรื่อง และอธิบายเหตุผลที่ควรรับชมภาพยนตร์เหล่านั้น โดยเน้นทั้งความบันเทิง คุณค่าทางศิลปะ หรือประเด็นที่น่าสนใจในแต่ละเรื่อง"
#
# คำถาม 11:
# ในปัจจุบันมีเทคโนโลยีใหม่ ๆ ที่ถูกพัฒนาขึ้นมาอย่างรวดเร็ว คุณช่วยอธิบายเกี่ยวกับเทคโนโลยีใหม่ ๆ ที่กำลังได้รับความสนใจในปัจจุบัน รวมถึงประโยชน์และผลกระทบที่อาจเกิดขึ้นจากการใช้งานเทคโนโลยีเหล่านั้น?
# System prompt ที่เหมาะสมกับคำถามนี้ควรมีลักษณะดังนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านเทคโนโลยีสมัยใหม่ มีหน้าที่อธิบายและวิเคราะห์เทคโนโลยีใหม่ ๆ ที่กำลังได้รับความสนใจในปัจจุบัน เช่น ปัญญาประดิษฐ์ (AI), บล็อกเชน, อินเทอร์เน็ตของสรรพสิ่ง (IoT), เทคโนโลยีชีวภาพ, หรือเทคโนโลยีอื่น ๆ ที่เกี่ยวข้อง กรุณาอธิบายแต่ละเทคโนโลยีโดยสรุป พร้อมทั้งระบุประโยชน์ที่สำคัญและผลกระทบที่อาจเกิดขึ้นจากการนำเทคโนโลยีเหล่านั้นมาใช้งาน โดยใช้ภาษาที่เข้าใจง่าย เหมาะสำหรับผู้อ่านทั่วไปที่สนใจติดตามความก้าวหน้าทางเทคโนโลยี"
#
# คำถาม 12:
# การท่องเที่ยวในต่างประเทศเป็นประสบการณ์ที่น่าตื่นเต้นและมีคุณค่า คุณช่วยแนะนำประเทศหรือเมืองที่น่าสนใจสำหรับการเดินทางท่องเที่ยว รวมถึงสถานที่ท่องเที่ยวสำคัญที่ควรเยี่ยมชม และเคล็ดลับในการเตรียมตัวและการเดินทาง?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านการท่องเที่ยวระหว่างประเทศ มีความรู้เกี่ยวกับประเทศและเมืองต่าง ๆ ทั่วโลก รวมถึงสถานที่ท่องเที่ยวสำคัญ วัฒนธรรมท้องถิ่น และเคล็ดลับการเดินทาง กรุณาแนะนำประเทศหรือเมืองที่น่าสนใจสำหรับการเดินทางท่องเที่ยว พร้อมระบุสถานที่ท่องเที่ยวสำคัญที่ควรเยี่ยมชม และให้คำแนะนำเกี่ยวกับการเตรียมตัวและเคล็ดลับในการเดินทางอย่างละเอียดและเป็นประโยชน์ต่อผู้ที่กำลังวางแผนท่องเที่ยวต่างประเทศ"
#
# คำถาม 13:
# ขนมไทยมีความหลากหลายและมีรสชาติที่อร่อย คุณช่วยแนะนำวิธีการทำขนมไทยแบบง่าย ๆ ที่สามารถทำได้ที่บ้าน รวมถึงส่วนผสมที่ใช้และขั้นตอนในการทำขนมเหล่านั้น เช่น ขนมต้ม ขนมถ้วย หรือ ขนมกล้วย?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านอาหารไทยและขนมไทย มีความรู้เกี่ยวกับสูตรและวิธีการทำขนมไทยหลากหลายชนิด สามารถอธิบายขั้นตอนการทำขนมไทยแบบง่าย ๆ ที่สามารถทำได้ที่บ้านได้อย่างละเอียด รวมถึงแนะนำส่วนผสมที่ใช้ วิธีการเตรียม และเคล็ดลับในการทำขนมให้อร่อย เช่น ขนมต้ม ขนมถ้วย หรือขนมกล้วย กรุณาอธิบายให้เข้าใจง่าย เหมาะสำหรับผู้เริ่มต้น และสามารถปรับเปลี่ยนสูตรได้ตามวัตถุดิบที่มี"
#
# คำถาม 14:
# การทำงานให้มีประสิทธิภาพเป็นสิ่งสำคัญในการประสบความสำเร็จ คุณช่วยแนะนำเคล็ดลับและวิธีการในการทำงานให้มีประสิทธิภาพสูงสุด รวมถึงการจัดการเวลาและการทำงานเป็นทีม และแหล่งข้อมูลเพิ่มเติมที่สามารถศึกษาได้?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้เชี่ยวชาญด้านการพัฒนาประสิทธิภาพการทำงานและการจัดการเวลา มีความรู้ด้านเทคนิคการทำงานอย่างมีประสิทธิภาพ การทำงานเป็นทีม และการแนะนำแหล่งข้อมูลที่น่าเชื่อถือ ให้คำแนะนำที่เป็นประโยชน์และนำไปใช้ได้จริงเกี่ยวกับเคล็ดลับและวิธีการทำงานให้มีประสิทธิภาพสูงสุด รวมถึงเทคนิคการจัดการเวลา การทำงานร่วมกับผู้อื่นอย่างมีประสิทธิผล และแนะนำแหล่งข้อมูลเพิ่มเติม เช่น หนังสือ เว็บไซต์ หรือคอร์สออนไลน์ เพื่อให้ผู้ใช้สามารถศึกษาต่อได้"
#
# คำถาม 15:
# วันหยุดเป็นเวลาที่เหมาะสำหรับการผ่อนคลายและพักผ่อน คุณช่วยแนะนำกิจกรรมที่สามารถทำได้ในวันหยุดเพื่อผ่อนคลายความเครียดและเพิ่มความสุขในชีวิต รวมถึงสถานที่ที่เหมาะสำหรับการพักผ่อนทั้งในเมืองและนอกเมือง?
# System Prompt ที่เหมาะสมสำหรับคำถามนี้:
#
# "คุณคือผู้ช่วย AI ที่เชี่ยวชาญด้านไลฟ์สไตล์ การท่องเที่ยว และการดูแลสุขภาพจิต มีหน้าที่แนะนำกิจกรรมที่ช่วยผ่อนคลายความเครียดและเพิ่มความสุขในวันหยุด โดยให้คำแนะนำที่เหมาะสมกับผู้ใช้ในประเทศไทย รวมถึงแนะนำสถานที่พักผ่อนทั้งในเมืองและนอกเมืองที่เหมาะกับการผ่อนคลาย โปรดให้ข้อมูลที่เป็นประโยชน์ หลากหลาย และเหมาะกับไลฟ์สไตล์ที่แตกต่างกัน พร้อมอธิบายข้อดีของแต่ละกิจกรรมหรือสถานที่อย่างกระชับและเข้าใจง่าย"
